# %% [markdown]
# ### ДЗ к 3 уроку

# %% [markdown]
# # 0 Задания к уроку 2
#
# ## 1. Задание
# Даны два вектора в трехмерном пространстве: (10,10,10) и (0,0,-10)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D
from pylab import *
import numpy as np
from scipy.optimize import fsolve

# %% [markdown]
#     1. Найдите их сумму. (на листочке)

# %%
a = np.array([10,10,10])
b = np.array([0,0,-10])

c = a + b

print(c)
# Out:
# [10 10  0]

# %% [markdown]
#     2. Напишите код на Python, реализующий расчет длины вектора, заданного его координатами. (в программе)

# %%
np.linalg.norm(c)
# Out:
# 14.142135623730951

# %% [markdown]
# ## 3. Задание

# %% [markdown]
#     1. Построение окружности.

# %%
x = np.linspace(-10,10,100000)
plt.figure(figsize = (10, 10))

y = (9 - x**2)**0.5
y2 = -(9 - x**2)**0.5

plt.plot(x,y)
plt.plot(x,y2)
plt.axis('scaled')
plt.show()
# Out:
# /var/folders/c4/gfl3dzhd2w90sn809ndq2z9m0000gn/T/ipykernel_3323/966495306.py:4: RuntimeWarning: invalid value encountered in sqrt
#   y = (9 - x**2)**0.5
# /var/folders/c4/gfl3dzhd2w90sn809ndq2z9m0000gn/T/ipykernel_3323/966495306.py:5: RuntimeWarning: invalid value encountered in sqrt
#   y2 = -(9 - x**2)**0.5

# %% [markdown]
#     2. Построение элипса.

# %%
x = np.linspace(-10,10,100000)
y = (1 - x**2/10)**0.5
y2 = -(1-x**2/10)**0.5
plt.figure(figsize = (10, 10))

plt.plot(x,y)
plt.plot(x,y2)
plt.axis('scaled')
plt.show()
# Out:
# /var/folders/c4/gfl3dzhd2w90sn809ndq2z9m0000gn/T/ipykernel_3323/2573018031.py:2: RuntimeWarning: invalid value encountered in sqrt
#   y = (1 - x**2/10)**0.5
# /var/folders/c4/gfl3dzhd2w90sn809ndq2z9m0000gn/T/ipykernel_3323/2573018031.py:3: RuntimeWarning: invalid value encountered in sqrt
#   y2 = -(1-x**2/10)**0.5

# %% [markdown]
#     3. Построение гиперболы.

# %%
x = np.linspace(-10,10,10000)
y = (1 + x**2)**0.5
y2 = -(1 + x**2)**0.5
plt.figure(figsize = (10, 10))

plt.plot(x,y)
plt.plot(x,y2)
plt.axis('scaled')
plt.show()

# %% [markdown]
# ## 5. Задание (в программе)

# %% [markdown]
#  1. Нарисуйте трехмерный график двух параллельных плоскостей.

# %%
fig = figure(figsize = (10, 10))
ax = Axes3D(fig)
x = np.arange(-10, 10, 1)
y = np.arange(-10, 10, 1)

x,y = np.meshgrid(x,y)

z = 5*x + 40
z2 = 5*x 
ax.plot_wireframe(x,y,z, colors = 'red')
ax.plot_surface(x,y,z2)

None
# Out:
# /var/folders/c4/gfl3dzhd2w90sn809ndq2z9m0000gn/T/ipykernel_3323/1482667431.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %% [markdown]
#  2. Нарисуйте трехмерный график двух любых поверхностей второго порядка.

# %%
fig = figure(figsize = (10, 10))
ax = Axes3D(fig)

x = np.arange(-10, 10,0.5)
y = np.arange(-10, 10,0.5)

x,y = np.meshgrid(x,y)

z = x**2 + y**2
z2 = -(np.sqrt((10*x)**2 + (y-50)**2))
ax.plot_surface(x, y, z)
ax.plot_surface(x, y, z2)


None
# Out:
# /var/folders/c4/gfl3dzhd2w90sn809ndq2z9m0000gn/T/ipykernel_3323/3434243997.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %% [markdown]
# # Задание 33

# %% [markdown]
#  1. Задание (в программе)

# %% [markdown]
# Нарисуйте график функции:   для некоторых (2-3 различных) значений параметров k, a, b

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 100)
k, a, b = np.linspace(8, 10, num = 3)
k1, a1, b1 = np.linspace(5, -3, num = 3)
k2, a2, b2 = np.linspace(-16, 21, num = 3)

plt.figure(figsize = (20, 5))
plt.plot(x, k * np.cos(x - a) + b, color = 'blue')
plt.plot(x, k1 * np.cos(x - a1) + b1, color='black')
plt.plot(x, k2 * np.cos(x - a2) + b2, color='brown')

plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()

# %% [markdown]
#  3. Задание (в программе)

# %% [markdown]
# Напишите код, который будет переводить полярные координаты в декартовы.

# %%
def polar_decart(r,rad):
    x = r*math.cos(rad)
    y = r*math.sin(rad)
    return x,y

polar_decart(np.sqrt(2)*2, np.pi/4)
# Out:
# (2.0000000000000004, 2.0)

# %% [markdown]
# Напишите код, который будет рисовать график окружности в полярных координатах.

# %%
r = np.arange(0, 2, 0.001)*np.pi 
plt.figure(figsize = (10, 5))
plt.polar(r, [1]*len(r)) 

plt.show()

# %% [markdown]
# Напишите код, который будет рисовать график отрезка прямой линии в полярных координатах.

# %%
r = np.arange(0, 2, 1)*np.pi 
plt.figure(figsize = (10, 5))

plt.polar(r, [1]*len(r)) 

plt.show()

# %% [markdown]
# ## 4. Задание (в программе)
#
# ### Решите систему уравнений:
#
# exp(x) + x∙(1 – y) = 1
# y = x^2 – 1

# %%
x = np.linspace(-6, 6, 100)

plt.figure(figsize = (12, 12))
plt.plot(x, (np.exp(x)+ x - 1)/x)
plt.plot(x, x**2 - 1)
plt.show()

def f(n):
    x, y = n
    return (x**2 - 1 - y, np.exp(x) + x * (1 - y) - 1)

x1, y1 =  fsolve(f, (2, 4))
x2, y2 =  fsolve(f, (-1, 1))
              
print (x1, y1)
print (x2, y2)
# Out:
# 2.618145573277872 5.854686243439231
# -1.5818353528983808 1.502203083669976
